# %% [markdown]
# # Merge all AUC and Threshold summary tables

# %% [markdown]
# # Set up

# %%
main_dir <- "../8_ROC"                               # CHANGE THIS

# %% [markdown]
# # Pattern match and read for summary AUCs for the relationships

# %%
#AUCs

files1 <- list.files(
  path = main_dir,
  pattern = "^AUC_summary.*\\.txt$",       #scan all AUC summary files for each relationship
  recursive = TRUE,
  full.names = TRUE
)

if (length(files1) == 0) stop("No matching AUC_summary*.txt files found")

#Thresholds

files2 <- list.files(
  path = main_dir,
  pattern = "LR_thresholds_youden_closest\\.csv$",       #scan all thresholds summary files for each relationship
  recursive = TRUE,
  full.names = TRUE
)

if (length(files2) == 0) stop("No matching Threshold files found")

# %% [markdown]
# # Create the merged file

# %%
#AUC
merged1 <- do.call(
  rbind,
  lapply(files1, function(f) {
    df <- read.table(f, sep = "\t", header = TRUE, stringsAsFactors = FALSE, check.names = FALSE)
    df$source_file <- strsplit(basename(f), "_")[[1]][3]
    df <- df[, c("source_file", setdiff(names(df), "source_file"))]       #put relationship labels in first column
    df
  })
)

print(merged1)

#Thresholds
merged2 <- do.call(
  rbind,
  lapply(files2, function(f) {
    df <- read.table(f, sep = "\t", header = TRUE, stringsAsFactors = FALSE, check.names = FALSE)
    # df$source_file <- strsplit(basename(f), "_")[[1]][3]
    # df <- df[, c("source_file", setdiff(names(df), "source_file"))]       #put relationship labels in first column
    df
  })
)

print(merged2)
# Out:
#    source_file          Panel       AUC AUC_CI_lower AUC_CI_upper N_sim
# 1          Duo         23astr 1.0000000    1.0000000    1.0000000 10000
# 2          Duo        90iisnp 0.9999998    0.9999994    1.0000000 10000
# 3          Duo        94iisnp 0.9999999    0.9999996    1.0000000 10000
# 4          Duo 23astr-90iisnp 1.0000000    1.0000000    1.0000000 10000
# 5          Duo 23astr-94iisnp 1.0000000    1.0000000    1.0000000 10000
# 6         Trio         23aSTR 1.0000000    1.0000000    1.0000000 10000
# 7         Trio        90iisnp 1.0000000    1.0000000    1.0000000 10000
# 8         Trio        94iisnp 1.0000000    1.0000000    1.0000000 10000
# 9         Trio 23astr-90iisnp 1.0000000    1.0000000    1.0000000 10000
# 10        Trio 23astr-94iisnp 1.0000000    1.0000000    1.0000000 10000
# 11          FS         23aSTR 0.9999040    0.9998700    0.9999380 10000
# 12          FS        90iisnp 0.9998402    0.9997893    0.9998912 10000
# 13          FS        94iisnp 0.9998909    0.9998470    0.9999348 10000
# 14          FS 23astr-90iisnp 1.0000000    1.0000000    1.0000000 10000
# 15          FS 23astr-94iisnp 1.0000000    1.0000000    1.0000000 10000
# 16          HS         23aSTR 0.9744071    0.9726334    0.9761808 10000
# 17          HS        90iisnp 0.9541908    0.9516365    0.9567451 10000
# 18          HS        94iisnp 0.9586201    0.9562004    0.9610398 10000
# 19          HS 23astr-90iisnp 0.9955660    0.9950209    0.9961110 10000
# 20          HS 23astr-94iisnp 0.9955461    0.9949923    0.9960998 10000
# 21        GPGC         23aSTR 0.9756187    0.9738900    0.9773474 10000
# 22        GPGC        90iisnp 0.9552477    0.9527110    0.9577845 10000
# 23        GPGC        94iisnp 0.9590161    0.9566091    0.9614231 10000
# 24        GPGC 23astr-90iisnp 0.9953329    0.9947512    0.9959147 10000
# 25        GPGC 23astr-94iisnp 0.9957255    0.9951839    0.9962671 10000
# 26         UNI         23aSTR 0.9765364    0.9748477    0.9782252 10000
# 27         UNI        90iisnp 0.9528625    0.9502308    0.9554942 10000
# 28         UNI        94iisnp 0.9578010    0.9553598    0.9602423 10000
# 29         UNI 23astr-90iisnp 0.9954642    0.9949024    0.9960260 10000
# 30         UNI 23astr-94iisnp 0.9956380    0.9951022    0.9961738 10000
# 31          FC         23aSTR 0.8419127    0.8365616    0.8472639 10000
# 32          FC        90iisnp 0.7968228    0.7907579    0.8028876 10000
# 33          FC        94iisnp 0.8104133    0.8045383    0.8162883 10000
# 34          FC 23astr-90iisnp 0.8980137    0.8938127    0.9022147 10000
# 35          FC 23astr-94iisnp 0.9039524    0.8998978    0.9080069 10000
#    AUC_diff_vs_ref AUC_diff_CI_lower AUC_diff_CI_upper      p_Delong
# 1               NA                NA                NA            NA
# 2      -0.00000022     -6.430753e-07      2.030753e-07  3.081150e-01
# 3      -0.00000015     -4.085165e-07      1.085165e-07  2.554391e-01
# 4       0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 5       0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 6               NA                NA                NA            NA
# 7       0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 8       0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 9       0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 10      0.00000000      0.000000e+00      0.000000e+00  1.000000e+00
# 11              NA                NA                NA            NA
# 12     -0.00006374     -1.250624e-04     -2.417612e-06  4.162652e-02
# 13     -0.00001307     -6.861204e-05      4.247204e-05  6.446455e-01
# 14      0.00009601      6.198082e-05      1.300392e-04  3.205121e-08
# 15      0.00009602      6.199082e-05      1.300492e-04  3.194618e-08
# 16              NA                NA                NA            NA
# 17     -0.02021633     -2.332798e-02     -1.710468e-02  3.834311e-37
# 18     -0.01578700     -1.878242e-02     -1.279158e-02  5.169227e-25
# 19      0.02115883      1.931278e-02      2.300487e-02 9.222110e-112
# 20      0.02113893      1.928050e-02      2.299735e-02 4.231436e-110
# 21              NA                NA                NA            NA
# 22     -0.02037094     -2.341829e-02     -1.732359e-02  3.208392e-39
# 23     -0.01660259     -1.956916e-02     -1.363601e-02  5.384900e-28
# 24      0.01971425      1.788802e-02      2.154048e-02  2.330813e-99
# 25      0.02010682      1.828982e-02      2.192383e-02 2.615985e-104
# 26              NA                NA                NA            NA
# 27     -0.02367393     -2.680053e-02     -2.054732e-02  8.030240e-50
# 28     -0.01873537     -2.169488e-02     -1.577586e-02  2.373763e-35
# 29      0.01892780      1.714748e-02      2.070813e-02  1.971147e-96
# 30      0.01910157      1.732941e-02      2.087374e-02  4.612704e-99
# 31              NA                NA                NA            NA
# 32     -0.04508998     -5.318908e-02     -3.699088e-02  1.013770e-27
# 33     -0.03149947     -3.945068e-02     -2.354826e-02  8.191755e-15
# 34      0.05610093      4.931148e-02      6.289038e-02  5.461929e-59
# 35      0.06203963      5.532193e-02      6.875732e-02  3.142498e-73
#    p_Delong_Holm Holm_significant_01
# 1             NA               FALSE
# 2   1.000000e+00               FALSE
# 3   1.000000e+00               FALSE
# 4   1.000000e+00               FALSE
# 5   1.000000e+00               FALSE
# 6             NA               FALSE
# 7   1.000000e+00               FALSE
# 8   1.000000e+00               FALSE
# 9   1.000000e+00               FALSE
# 10  1.000000e+00               FALSE
# 11            NA               FALSE
# 12  8.325303e-02               FALSE
# 13  6.446455e-01               FALSE
# 14  1.277847e-07                TRUE
# 15  1.277847e-07                TRUE
# 16            NA               FALSE
# 17  7.668622e-37                TRUE
# 18  5.169227e-25                TRUE
# 19 3.688844e-111                TRUE
# 20 1.269431e-109                TRUE
# 21            NA               FALSE
# 22  6.416783e-39                TRUE
# 23  5.384900e-28                TRUE
# 24  6.992438e-99                TRUE
# 25 1.046394e-103                TRUE
# 26            NA               FALSE
# 27  1.606048e-49                TRUE
# 28  2.373763e-35                TRUE
# 29  5.913442e-96                TRUE
# 30  1.845082e-98                TRUE
# 31            NA               FALSE
# 32  2.027540e-27                TRUE
# 33  8.191755e-15                TRUE
# 34  1.638579e-58                TRUE
# 35  1.256999e-72                TRUE
#    Panel,Relationship,threshold,sensitivity,specificity,threshold.1,sensitivity.1,specificity.1
# 1                                        23astr,Duo,-1.73995102687869,1,1,-1.73995102687869,1,1
# 2                                23astr-90iisnp,Duo,-3.52379282388801,1,1,-3.52379282388801,1,1
# 3                                23astr-94iisnp,Duo,-5.58047978750428,1,1,-5.58047978750428,1,1
# 4                         90iisnp,Duo,-4.9526356529602,1,0.9998,-3.27676874187626,0.9999,0.9999
# 5                   90iisnp,Duo,-3.27676874187626,0.9999,0.9999,-3.27676874187626,0.9999,0.9999
# 6                             94iisnp,Duo,-2.20005581838387,1,0.9998,-2.20005581838387,1,0.9998
# 7                                       23aSTR,Trio,-3.28557719142542,1,1,-3.28557719142542,1,1
# 8                               23astr-90iisnp,Trio,-23.1464462407071,1,1,-23.1464462407071,1,1
# 9                               23astr-94iisnp,Trio,-27.1529472556362,1,1,-27.1529472556362,1,1
# 10                                     90iisnp,Trio,-9.61831716385939,1,1,-9.61831716385939,1,1
# 11                                     94iisnp,Trio,-8.98230256416399,1,1,-8.98230256416399,1,1
# 12                  23aSTR,FS,0.0250904182399388,0.9951,0.9957,0.0250904182399388,0.9951,0.9957
# 41              94iisnp,GPGC,-0.118028833459574,0.9104,0.8709,-0.0554466247400222,0.9001,0.8805
# 42              94iisnp,GPGC,-0.114957832455025,0.9099,0.8714,-0.0554466247400222,0.9001,0.8805
# 43              94iisnp,GPGC,-0.107627932254525,0.9086,0.8727,-0.0554466247400222,0.9001,0.8805
# 44              94iisnp,GPGC,-0.103885954476522,0.9079,0.8734,-0.0554466247400222,0.9001,0.8805
# 45              94iisnp,GPGC,-0.100509720393281,0.9072,0.8741,-0.0554466247400222,0.9001,0.8805
# 46               23aSTR,UNI,-0.0489207622213153,0.9227,0.9218,-0.0489207622213153,0.9227,0.9218
# 47               23aSTR,UNI,-0.0424320328000194,0.9218,0.9227,-0.0424320328000194,0.9218,0.9227
# 48               23aSTR,UNI,-0.0416942082241538,0.9216,0.9229,-0.0489207622213153,0.9227,0.9218
# 49                23aSTR,UNI,-0.0412880329032379,0.9215,0.923,-0.0424320328000194,0.9218,0.9227
# 50         23astr-90iisnp,UNI,-0.095319839564709,0.9733,0.9615,-0.0173579881815959,0.9696,0.965
# 51         23astr-90iisnp,UNI,-0.092412297289924,0.9732,0.9616,-0.0173579881815959,0.9696,0.965
# 52       23astr-94iisnp,UNI,-0.0138728002091647,0.9703,0.9678,-0.0138728002091647,0.9703,0.9678
# 53                90iisnp,UNI,-0.011080474749168,0.8856,0.8813,-0.011080474749168,0.8856,0.8813
# 54              94iisnp,UNI,0.00373403143767687,0.8899,0.8869,0.00373403143767687,0.8899,0.8869
# 55                 23aSTR,FC,0.0036608294481245,0.7439,0.7803,-0.0328118272001496,0.7608,0.7624
# 56                23aSTR,FC,0.00372757479722441,0.7438,0.7804,-0.0328118272001496,0.7608,0.7624
# 57                23aSTR,FC,0.00386964048797124,0.7437,0.7805,-0.0328118272001496,0.7608,0.7624
# 58        23astr-90iisnp,FC,-0.0130521219348048,0.8186,0.8152,-0.0130521219348048,0.8186,0.8152
# 59          23astr-94iisnp,FC,0.0593456236284757,0.8001,0.8465,0.0192492442068188,0.8111,0.8353
# 60              90iisnp,FC,-0.0206838576116334,0.7399,0.7067,-0.00458179169098199,0.7298,0.7165
# 61                   94iisnp,FC,0.0394517940621541,0.7071,0.763,-0.0168511263433044,0.74,0.7283

# %% [markdown]
# # Save file

# %%
write.table(merged1, file = file.path(main_dir, "AUC_CI_DeLong_summary_merged.txt"),
            sep = "\t", quote = FALSE, row.names = FALSE)

write.table(merged2, file = file.path(main_dir, "Threshold_summary_merged.csv"),
            sep = "\t", quote = FALSE, row.names = FALSE)

cat("Merged", length(files1), "files into", file.path(main_dir, "AUC_CI_DeLong_summary_merged.txt"), "\n")
cat("Merged", length(files2), "files into", file.path(main_dir, "Threshold_summary_merged.csv"), "\n")
# Out:
# Merged 7 files into ../8_ROC/AUC_CI_DeLong_summary_merged.txt
# Merged 7 files into ../8_ROC/Threshold_summary_merged.csv
